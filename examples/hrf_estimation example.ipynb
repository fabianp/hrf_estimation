# %% [markdown]
# ## Usage example of hrf_estimation
#
# We will use sample data to estimate the HRF and activation pattern using <code>hrf_estimation</code>

# %%
# import packages we will need
# %pylab inline
import hrf_estimation as he
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Now we will load some sample data. This data is described in the paper “Identifying natural images from human brain activity.,” K. N. Kay et al. Nature 2008, and is publicly available from http://crcns.org.
#
# The following function will download the data to temporary file and perform a local detrending (Savitzky-Golay filter) before returning it.
#
# The returned data consist of an array of 500 voxel timecourses, a list of conditions representing the condition ID and a list of onseets representing the time onset of its relative condition. The list of conditions and onsets have the same length. The repetition time (TR) for this dataset is 1 second.

# %%
voxels, conditions, onsets = he.data.get_sample_data(0, full_brain=False)
print('Num of timepoints in a single voxel: %s' % voxels.shape[0])
print('Num of voxels: %s' % voxels.shape[1])
print('Num of conditions: %s' % len(conditions))
print('Num of onsets: %s' % len(onsets))
# Out:
# Downloading BOLD signal
# Performed Savitzky-Golay
# Num of timepoints in a single voxel: 3360
# Num of voxels: 500
# Num of conditions: 700
# Num of onsets: 700

# %%
# plot one voxel
import prettyplotlib as ppl
ppl.plot(voxels[:, 0])
plt.xlabel('Timecourse (in seconds)')
plt.show()

# %% [markdown]
# The <code>glm</code> function in <code>hrf_estimation</code>

# %%
# we call he.glm with our data and a TR of 1 second
# we also specify the basis function for the HRF estimation
hrfs, betas = he.glm(conditions, onsets, 1., voxels, basis='fir')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d20555d2ada9> in <module>()
#       1 # we call he.glm with our data and a TR of 1 second
#       2 # we also specify the basis function for the HRF estimation
# ----> 3 hrfs, betas = he.glm(conditions, onsets, 1., voxels, basis='fir')
#
# //anaconda/lib/python2.7/site-packages/hrf_estimation-0.4.3-py2.7.egg/hrf_estimation/rank_one_.pyc in glm(conditions, onsets, TR, Y, basis, mode, hrf_length, oversample, ref_hrf, rtol, verbose, maxiter, callback, method, n_jobs, init, return_design_matrix, return_raw_U, cache)
#     381
#     382     X_design, Q = _create_design_matrix(
# --> 383         conditions, onsets, TR, n_scans, basis, oversample, hrf_length)
#     384     if verbose > 0:
#     385         print('.. done creating design matrix ..')
#
# //anaconda/lib/python2.7/site-packages/hrf_estimation-0.4.3-py2.7.egg/hrf_estimation/utils.pyc in create_design_matrix(conditions, onsets, TR, n_scans, basis, oversample, hrf_length)
#      52             design_matrix_cols.append(col[::oversample])
#      53
# ---> 54     design_matrix = np.array(design_matrix_cols).T
#      55     assert design_matrix.shape[0] == n_scans
#      56     return design_matrix, np.asarray(B).T[::oversample] # XXX hrf_length
#
# KeyboardInterrupt:

# %%
ppl.plot(hrfs)
plt.show()
